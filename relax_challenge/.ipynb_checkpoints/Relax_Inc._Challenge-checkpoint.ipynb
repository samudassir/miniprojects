# %% [markdown]
# # Take Home Challenge

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
users = pd.read_csv("takehome_users.csv")
usage = pd.read_csv("takehome_user_engagement.csv")

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
# object_id                     12000 non-null int64
# creation_time                 12000 non-null object
# name                          12000 non-null object
# email                         12000 non-null object
# creation_source               12000 non-null object
# last_session_creation_time    8823 non-null float64
# opted_in_to_mailing_list      12000 non-null int64
# enabled_for_marketing_drip    12000 non-null int64
# org_id                        12000 non-null int64
# invited_by_user_id            6417 non-null float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 937.6+ KB

# %%
users.nunique()
# Out:
# object_id                     12000
# creation_time                 11996
# name                          11355
# email                         11980
# creation_source                   5
# last_session_creation_time     8821
# opted_in_to_mailing_list          2
# enabled_for_marketing_drip        2
# org_id                          417
# invited_by_user_id             2564
# dtype: int64

# %%
users.groupby('creation_source')['object_id'].count().plot(kind='bar',color='blue', alpha=0.4)
plt.title('User Registration from different sources')
plt.xlabel('creation_source')
plt.ylabel('Registered Users')
_ = plt.rcParams['figure.figsize'] = [20, 15]
plt.show()

# %%
users['Year_Created'] = pd.DatetimeIndex(users['creation_time']).year
users['Month_Created'] = pd.DatetimeIndex(users['creation_time']).month

# %%
users.groupby(['Year_Created','Month_Created'])['object_id'].count().plot(kind='bar',color='blue', alpha=0.4)
plt.title('User Registration over period of 2 years')
plt.xlabel('Year_Month')
plt.ylabel('Registered Users')
plt.show()

# %%
usage_agg = usage.groupby(['user_id'])['visited'].sum().reset_index()

# %%
usage_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8823 entries, 0 to 8822
# Data columns (total 2 columns):
# user_id    8823 non-null int64
# visited    8823 non-null int64
# dtypes: int64(2)
# memory usage: 137.9 KB

# %%
users_usg_agg = pd.merge( users, usage_agg, left_on='object_id',right_on='user_id',how='left').fillna(0)

# %%
users_usg_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12000 entries, 0 to 11999
# Data columns (total 14 columns):
# object_id                     12000 non-null int64
# creation_time                 12000 non-null object
# name                          12000 non-null object
# email                         12000 non-null object
# creation_source               12000 non-null object
# last_session_creation_time    12000 non-null float64
# opted_in_to_mailing_list      12000 non-null int64
# enabled_for_marketing_drip    12000 non-null int64
# org_id                        12000 non-null int64
# invited_by_user_id            12000 non-null float64
# Year_Created                  12000 non-null int64
# Month_Created                 12000 non-null int64
# user_id                       12000 non-null float64
# visited                       12000 non-null float64
# dtypes: float64(4), int64(6), object(4)
# memory usage: 1.4+ MB

# %%
sns.boxplot(x='creation_source',y='visited',data=users_usg_agg)
plt.title('Visits of Users Created from different Sources')
plt.xlabel('creation_source')
plt.ylabel('User Visits')
plt.show()

# %%
users_usg_agg.groupby('creation_source')['visited'].sum().plot(kind='bar',color='orange', alpha=0.4)
plt.title('Visits of Users Created from different Sources')
plt.xlabel('creation_source')
plt.ylabel('User Visits')
plt.show()

# %%
users_usg_agg_50 = users_usg_agg.nlargest(50,'visited')
users_usg_agg_50.groupby('invited_by_user_id')['object_id'].count().plot(kind='bar',color='orange', alpha=0.4)
plt.title('Visits of Invited Users')
plt.xlabel('invited_by_user_id')
plt.ylabel('User Visits')
plt.show()

# %%
from datetime import datetime, timedelta

def custom(x):
    """
    Takes property object x
    converts x to list
    returns 1 if a user logged into the product on three separate
    days in at least one seven day period 
    """
    if len(x) >= 3:  # condition to eliminate if user has less than 3 time stamps
        x = [i for i in x]  # convert property object to list
        x.sort()  # sort the dates in increasing order
        x = [x[i+1] - x[i] for i in range(len(x)-2)]  # compute cumulative difference of current and next day
        # sum i, i+1, i+2 terms and check if it`s less than 7 which gives if it`s in a seven day period
        x = [1 for i in range(len(x)-2) if x[i] + x[i+1] + x[i+2] <= timedelta(days=7)]
        # condition to check if there`s a 1 in x, return 1 if true
        if 1 in x:
            return 1
usage['time_stamp'] = pd.to_datetime(usage['time_stamp'])
df = usage.groupby('user_id').agg(custom)  # group by user_id and aggregate using custom function
df.fillna(0, inplace=True)  # fill null values with 0
df.columns = ['adopted_user']
df=df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8823 entries, 0 to 8822
# Data columns (total 2 columns):
# user_id         8823 non-null int64
# adopted_user    8823 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 137.9 KB

# %%
df['adopted_user'] = df['adopted_user'].astype(np.int)
#df['adopted_user'] = df['adopted_user'].astype(str)
df.head()
# Out:
#    user_id  adopted_user
# 0        1             0
# 1        2             0
# 2        3             0
# 3        4             0
# 4        5             0

# %%
adopted_users = pd.merge(df, users,left_on='user_id',right_on='object_id').fillna(0)
adopted_users.head(50)
# Out:
#     user_id  adopted_user  object_id        creation_time                name  \
# 0         1             0          1  2014-04-22 03:53:30      Clausen August
# 1         2             0          2  2013-11-15 03:45:04       Poole Matthew
# 2         3             0          3  2013-03-19 23:14:52   Bottrill Mitchell
# 3         4             0          4  2013-05-21 08:09:28     Clausen Nicklas
# 4         5             0          5  2013-01-17 10:14:20           Raw Grace
# 5         6             0          6  2013-12-17 03:37:06       Cunha Eduardo
# 6         7             0          7  2012-12-16 13:24:32        Sewell Tyler
# 7        10             1         10  2013-01-16 22:08:03        Santos Carla
# 8        11             0         11  2013-12-26 03:55:54      Paulsen Malthe
# 9        13             0         13  2014-03-30 16:19:38       Fry Alexander
# 10       14             0         14  2012-10-11 16:14:33         Rivera Bret
# 11       17             0         17  2014-04-09 14:39:38    Reynolds Anthony
# 12       19             0         19  2013-05-24 14:56:36      Collins Arlene
# 13       20             0         20  2014-03-06 11:46:38       Helms Mikayla
# 14       21             0         21  2013-01-22 12:27:42        Hunter Alfie
# 15       22             0         22  2014-02-10 06:00:46        Myers Jordan
# 16       23             0         23  2012-08-17 08:30:27         Souza Alice
# 17       24             0         24  2013-09-09 22:20:03      Woodruff James
# 18       25             0         25  2014-02-25 00:11:13         Stone Elise
# 19       27             0         27  2014-01-14 17:35:11         Santos Lu�s
# 20       28             0         28  2013-02-11 20:00:25   Weissmuller Marko
# 21       29             0         29  2013-09-16 02:08:41    Fernandes Evelyn
# 22       30             0         30  2013-06-04 00:44:25          Egger Leah
# 23       31             0         31  2014-01-23 05:21:42        Moffitt Lily
# 24       33             0         33  2014-03-11 06:29:09         Araujo Jos�
# 25       36             0         36  2013-08-06 09:08:15      Andresen Peter
# 26       37             0         37  2012-09-25 14:37:23      Carr-Glyn Ella
# 27       41             0         41  2014-04-30 23:38:17    Herman Christian
# 28       42             1         42  2012-11-11 19:05:07      Pinto Giovanna
# 29       43             1         43  2012-12-31 07:13:17      Gomes Beatrice
# 30       44             0         44  2014-05-28 16:43:12       Vogel Jessika
# 31       45             0         45  2014-04-29 21:55:19     Boxer Gabrielle
# 32       46             0         46  2014-01-01 18:42:08       Landry Juliet
# 33       47             0         47  2012-06-07 13:23:02    Carrillo Hillary
# 34       48             0         48  2013-11-03 14:37:00       Milton Randal
# 35       49             0         49  2013-10-13 10:06:52    Thompson Terence
# 36       50             0         50  2012-06-03 11:02:08  Oliveira Gabrielly
# 37       51             0         51  2013-08-22 09:53:43       Pereira Bruna
# 38       53             1         53  2013-02-09 23:47:15      Ribeiro Camila
# 39       54             0         54  2013-03-17 12:31:27    Nilsson Michelle
# 40       55             0         55  2012-07-18 23:00:26       Castro Arthur
# 41       56             0         56  2013-12-01 08:50:02       Beike Philipp
# 42       57             0         57  2013-11-18 17:48:04       Almeida Livia
# 43       58             0         58  2013-01-28 17:44:26      Sanchez Ernest
# 44       59             0         59  2014-03-07 03:21:57      Barbosa �gatha
# 45       60             0         60  2014-03-21 22:56:03    McEacharn Archie
# 46       61             0         61  2014-05-14 03:45:47         Melo Murilo
# 47       63             1         63  2012-12-20 16:30:52      Martins Leonor
# 48       64             0         64  2014-03-13 22:02:50         Curtis Kate
# 49       65             0         65  2013-08-27 00:38:29      Baier Christin
#
#                                   email     creation_source  \
# 0              AugustCClausen@yahoo.com        GUEST_INVITE
# 1                MatthewPoole@gustr.com          ORG_INVITE
# 2            MitchellBottrill@gustr.com          ORG_INVITE
# 3             NicklasSClausen@yahoo.com        GUEST_INVITE
# 4                    GraceRaw@yahoo.com        GUEST_INVITE
# 5         EduardoPereiraCunha@yahoo.com        GUEST_INVITE
# 6            TylerSewell@jourrapide.com              SIGNUP
# 7         CarlaFerreiraSantos@gustr.com          ORG_INVITE
# 8              MaltheAPaulsen@gustr.com              SIGNUP
# 9                AlexanderDFry@cuvox.de          ORG_INVITE
# 10                BretKRivera@gmail.com              SIGNUP
# 11       AnthonyReynolds@jourrapide.com        GUEST_INVITE
# 12             ArleneRCollins@gmail.com              SIGNUP
# 13                   lqyvjilf@uhzdq.com              SIGNUP
# 14                AlfieHunter@gmail.com   PERSONAL_PROJECTS
# 15                JordanMyers@gmail.com          ORG_INVITE
# 16           AliceAraujoSouza@gustr.com          ORG_INVITE
# 17              JamesTWoodruff@cuvox.de              SIGNUP
# 18            EliseStone@jourrapide.com        GUEST_INVITE
# 19            LuisPintoSantos@gmail.com          ORG_INVITE
# 20      MarkoWeissmuller@jourrapide.com              SIGNUP
# 21  EvelynSousaFernandes@jourrapide.com              SIGNUP
# 22             LeahEgger@jourrapide.com        GUEST_INVITE
# 23           LilyMoffitt@jourrapide.com              SIGNUP
# 24           JoseMartinsAraujo@cuvox.de        GUEST_INVITE
# 25              PeterTAndresen@cuvox.de        GUEST_INVITE
# 26              EllaCarr-Glyn@yahoo.com              SIGNUP
# 27          ChristianHerman@hotmail.com          ORG_INVITE
# 28          GiovannaCunhaPinto@cuvox.de              SIGNUP
# 29                   vgqmpljq@yyyxt.com        GUEST_INVITE
# 30          JessikaVogel@jourrapide.com              SIGNUP
# 31             GabrielleBoxer@gmail.com  SIGNUP_GOOGLE_AUTH
# 32              JulietTLandry@yahoo.com          ORG_INVITE
# 33           HillaryJCarrillo@yahoo.com          ORG_INVITE
# 34                   cawizywo@cslyn.com          ORG_INVITE
# 35         TerenceSThompson@hotmail.com              SIGNUP
# 36   GabriellyAlmeidaOliveira@gmail.com        GUEST_INVITE
# 37         BrunaCastroPereira@yahoo.com          ORG_INVITE
# 38         CamilaGomesRibeiro@gmail.com        GUEST_INVITE
# 39         MichelleMNilsson@hotmail.com        GUEST_INVITE
# 40        ArthurPereiraCastro@gmail.com  SIGNUP_GOOGLE_AUTH
# 41               PhilippBeike@gmail.com        GUEST_INVITE
# 42           LiviaMeloAlmeida@gmail.com        GUEST_INVITE
# 43        ErnestGSanchez@jourrapide.com          ORG_INVITE
# 44    AgathaCavalcantiBarbosa@gmail.com  SIGNUP_GOOGLE_AUTH
# 45            ArchieMcEacharn@gmail.com          ORG_INVITE
# 46          MuriloCorreiaMelo@gmail.com  SIGNUP_GOOGLE_AUTH
# 47        LeonorAraujoMartins@gmail.com  SIGNUP_GOOGLE_AUTH
# 48                   saxmsdmc@xhtxh.com              SIGNUP
# 49              ChristinBaier@gmail.com  SIGNUP_GOOGLE_AUTH
#
#     last_session_creation_time  opted_in_to_mailing_list  \
# 0                 1.398139e+09                         1
# 1                 1.396238e+09                         0
# 2                 1.363735e+09                         0
# 3                 1.369210e+09                         0
# 4                 1.358850e+09                         0
# 5                 1.387424e+09                         0
# 6                 1.356010e+09                         0
# 7                 1.401833e+09                         1
# 8                 1.388117e+09                         0
# 9                 1.396196e+09                         0
# 10                1.350058e+09                         0
# 11                1.397314e+09                         1
# 12                1.369926e+09                         1
# 13                1.401364e+09                         0
# 14                1.358858e+09                         0
# 15                1.392012e+09                         0
# 16                1.345279e+09                         1
# 17                1.378765e+09                         1
# 18                1.393373e+09                         1
# 19                1.389807e+09                         0
# 20                1.360872e+09                         0
# 21                1.379384e+09                         0
# 22                1.370307e+09                         0
# 23                1.390541e+09                         0
# 24                1.401518e+09                         0
# 25                1.375780e+09                         1
# 26                1.348670e+09                         0
# 27                1.398901e+09                         0
# 28                1.401045e+09                         1
# 29                1.366010e+09                         0
# 30                1.401382e+09                         0
# 31                1.398895e+09                         1
# 32                1.388602e+09                         0
# 33                1.339162e+09                         1
# 34                1.383576e+09                         0
# 35                1.381659e+09                         0
# 36                1.350990e+09                         0
# 37                1.377165e+09                         0
# 38                1.367798e+09                         0
# 39                1.363783e+09                         1
# 40                1.342825e+09                         0
# 41                1.385974e+09                         0
# 42                1.384883e+09                         0
# 43                1.359395e+09                         1
# 44                1.401593e+09                         0
# 45                1.400195e+09                         0
# 46                1.400039e+09                         0
# 47                1.401899e+09                         0
# 48                1.394921e+09                         0
# 49                1.377737e+09                         0
#
#     enabled_for_marketing_drip  org_id  invited_by_user_id  Year_Created  \
# 0                            0      11             10803.0          2014
# 1                            0       1               316.0          2013
# 2                            0      94              1525.0          2013
# 3                            0       1              5151.0          2013
# 4                            0     193              5240.0          2013
# 5                            0     197             11241.0          2013
# 6                            1      37                 0.0          2012
# 7                            1     318              4143.0          2013
# 8                            0      69                 0.0          2013
# 9                            0     254             11204.0          2014
# 10                           0       0                 0.0          2012
# 11                           0     175              1600.0          2014
# 12                           0       0                 0.0          2013
# 13                           0      58                 0.0          2014
# 14                           0      54                 0.0          2013
# 15                           0       7              2994.0          2014
# 16                           0       6                23.0          2012
# 17                           0     123                 0.0          2013
# 18                           0      81              6312.0          2014
# 19                           0     134              4189.0          2014
# 20                           0       6                 0.0          2013
# 21                           0      92                 0.0          2013
# 22                           0     251              4835.0          2013
# 23                           0     283                 0.0          2014
# 24                           0     401                79.0          2014
# 25                           0     109              6805.0          2013
# 26                           0     276                 0.0          2012
# 27                           0      64              9286.0          2014
# 28                           0     235                 0.0          2012
# 29                           0      63               149.0          2012
# 30                           0      14                 0.0          2014
# 31                           0       4                 0.0          2014
# 32                           0     127              2125.0          2014
# 33                           1      32             11800.0          2012
# 34                           0     224               526.0          2013
# 35                           0     304                 0.0          2013
# 36                           0      61                50.0          2012
# 37                           1       0              9093.0          2013
# 38                           0      37              3641.0          2013
# 39                           1      51              3876.0          2013
# 40                           0     229                 0.0          2012
# 41                           0     229                55.0          2013
# 42                           0      88              2436.0          2013
# 43                           0     304              6447.0          2013
# 44                           0     325                 0.0          2014
# 45                           0      88              3463.0          2014
# 46                           0     150                 0.0          2014
# 47                           0     203                 0.0          2012
# 48                           0      21                 0.0          2014
# 49                           0     409                 0.0          2013
#
#     Month_Created
# 0               4
# 1              11
# 2               3
# 3               5
# 4               1
# 5              12
# 6              12
# 7               1
# 8              12
# 9               3
# 10             10
# 11              4
# 12              5
# 13              3
# 14              1
# 15              2
# 16              8
# 17              9
# 18              2
# 19              1
# 20              2
# 21              9
# 22              6
# 23              1
# 24              3
# 25              8
# 26              9
# 27              4
# 28             11
# 29             12
# 30              5
# 31              4
# 32              1
# 33              6
# 34             11
# 35             10
# 36              6
# 37              8
# 38              2
# 39              3
# 40              7
# 41             12
# 42             11
# 43              1
# 44              3
# 45              3
# 46              5
# 47             12
# 48              3
# 49              8

# %%
adopted_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8823 entries, 0 to 8822
# Data columns (total 14 columns):
# user_id                       8823 non-null int64
# adopted_user                  8823 non-null int64
# object_id                     8823 non-null int64
# creation_time                 8823 non-null object
# name                          8823 non-null object
# email                         8823 non-null object
# creation_source               8823 non-null object
# last_session_creation_time    8823 non-null float64
# opted_in_to_mailing_list      8823 non-null int64
# enabled_for_marketing_drip    8823 non-null int64
# org_id                        8823 non-null int64
# invited_by_user_id            8823 non-null float64
# Year_Created                  8823 non-null int64
# Month_Created                 8823 non-null int64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 1.0+ MB

# %%
replace_creation_source = {"creation_source":     {"PERSONAL_PROJECTS": 1, "GUEST_INVITE": 2,"ORG_INVITE": 3,"SIGNUP": 4,"SIGNUP_GOOGLE_AUTH": 5}}
adopted_users.replace(replace_creation_source,inplace=True)

# %%
sns.heatmap(adopted_users.drop(['user_id','object_id','last_session_creation_time','name','creation_time','Year_Created','Month_Created'],axis=1).corr(), square=True, cmap='RdYlGn')

# %% [markdown]
# <h1> From above plots, we can conclude that below features impact the future user adoption</h1>
# <ul><li> Creation Source
# <li> Opted_in_to_mailing_list
# <li> Enabled for Marketing Drip
# <li> Invited by
# <li> OrgId </ul>
#
# <h3>Organizations when subscribe for the product, there are more chanced of ORG_INVITE users having better adoption rates</h3>

# %% [markdown]
# <h1>Recommendation:</h1>
# <h3>Relax Inc can have campaigns to onboard Organization Users</h3>
# <h3>Run programs for inviting users by existing users</h3>
# <h3>Makre sure Marketing emails reach the users</h3>

# %% [markdown]
# # NOTE : Other steps to follow would be to build a model to better predict the outcomes
